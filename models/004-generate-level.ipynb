# %%
import json
import os
from glob import glob
from random import sample
import librosa
from shutil import copyfile, rmtree
from distutils.dir_util import copy_tree
import torch
import torch.nn as nn
from torch.autograd import Variable
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers, all_characters):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.all_characters = all_characters
        
        self.encoder = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers)
        self.decoder = nn.Linear(hidden_size, output_size)
    
    def forward(self, input, hidden):
        input = self.encoder(input.view(1, -1))
        output, hidden = self.gru(input.view(1, 1, -1), hidden)
        output = self.decoder(output.view(1, -1))
        return output, hidden

    def init_hidden(self):
        return Variable(torch.zeros(self.n_layers, 1, self.hidden_size))
    
    def char_tensor(self, string):
        tensor = torch.zeros(len(string)).long()
        for c in range(len(string)):
            tensor[c] = self.all_characters.index(string[c])
        return Variable(tensor)


def evaluate(model, prime_str=['1107n9n9n9n9n9n9n9n9n9n9'], predict_len=1000, temperature=0.8):
    hidden = model.init_hidden()
    prime_input = model.char_tensor(prime_str)
    predicted = prime_str

    # Use priming string to "build up" hidden state
    for p in range(len(prime_str) - 1):
        _, hidden = model(prime_input[p], hidden)
    inp = prime_input[-1]
    
    for p in range(predict_len):
        output, hidden = model(inp, hidden)
        
        # Sample from the network as a multinomial distribution
        output_dist = output.data.view(-1).div(temperature).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        
        # Add predicted character to string and use as next input
        predicted_char = model.all_characters[top_i]
        predicted.append(predicted_char)
        inp = model.char_tensor([predicted_char])

    return predicted

# %%
with open('all_characters.json', 'r') as f:
    all_characters = json.loads(f.read())

with open('params.json', 'r') as f:
    params = json.loads(f.read())

n_characters = len(all_characters)
hidden_size = params['hidden_size']
n_layers = params['n_layers']

model = RNN(n_characters, hidden_size, n_characters, n_layers, all_characters)
model.load_state_dict(torch.load('model.pth'))
model.eval()
# Out:
# RNN(
#   (encoder): Embedding(15, 100)
#   (gru): GRU(100, 100)
#   (decoder): Linear(in_features=100, out_features=15, bias=True)
# )

# %%
temperature = 0.8
levels = ['Expert', 'ExpertPlus']
levels = ['Expert']
song_ids = ['vodka']

# %%
for song_id in song_ids:
    with open('selected_songs/' + song_id + '/info.dat', 'r') as f:
        std_info = json.loads(f.read())

    std_info['_levelAuthorName'] = 'MADD AI'
    
    rmtree('generated_songs/' + song_id + '_g', ignore_errors=True)
    os.makedirs('generated_songs/' + song_id + '_g')

    copyfile('selected_songs/' + song_id + '/' + std_info['_coverImageFilename'], 
             'generated_songs/' + song_id + '_g/' + std_info['_coverImageFilename'])
    copyfile('selected_songs/' + song_id + '/' + std_info['_songFilename'], 
             'generated_songs/' + song_id + '_g/' + std_info['_songFilename'])
    
    with open('generated_songs/' + song_id + '_g/info.dat', 'w') as f:
        f.write(json.dumps(std_info))
    
    for i in range(len(levels)):
        
        with open('selected_songs/' + song_id + '/' + levels[i] + '.dat', 'r') as f:
            data = json.loads(f.read())
        
        times = sorted(list(set([el['_time'] for el in data['_notes']])))
        first_beats = ['n9n9n9n9010101n9n9n9n9n9']
        seq = evaluate(model, first_beats, len(times) - len(first_beats), temperature=temperature)

        notes = []

        for j in range(len(seq)):
            for k in range(0, 24, 2):
                el = seq[j][k:k+2]

                if el[0] != 'n':
                    notes.append({
                        '_time': times[j],
                        '_lineIndex': k // 2 % 4,
                        '_lineLayer': k // 2 // 4,
                        '_type': int(el[0]),
                        '_cutDirection': int(el[1])            
                    })
        
        data['_notes'] = notes
        
        with open('generated_songs/' + song_id + '_g/' + levels[i] + '.dat', 'w') as f:
            f.write(json.dumps(data))

# %%
for song_id in song_ids:
    for i in range(len(levels)):
        
        with open('selected_songs/' + song_id + '/' + levels[i] + '.dat', 'r') as f:
            data = json.loads(f.read())
        
        times = sorted(list(set([el['_time'] for el in data['_notes']])))
        first_beats = ['n9n9n9n9010101n9n9n9n9n9']
        seq = evaluate(model, first_beats, len(times) - len(first_beats), temperature=temperature)

        notes = []

        for j in range(len(seq)):
            for k in range(0, 24, 2):
                el = seq[j][k:k+2]

                if el[0] != 'n':
                    notes.append({
                        '_time': times[j],
                        '_lineIndex': k // 2 % 4,
                        '_lineLayer': k // 2 // 4,
                        '_type': int(el[0]),
                        '_cutDirection': int(el[1])            
                    })

# %%
print('[')
for el in notes:
    print('{')
    print(f""" "_time": {el['_time']}, "_lineIndex": {el['_lineIndex']}, "_lineLayer": {el['_lineLayer']}, "_type": {el['_type']}, "_cutDirection": {el['_cutDirection']} """)
    print('},')
print(']')
# Out:
# [
# {
#  "_time": 4, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 4, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 4, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 4.5, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 8, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 8.5, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 12, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 12.5, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 16, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 16.5, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 17, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 17.5, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 18, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 18, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 18.5, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 19, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 20, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 21, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 22, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 23, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 24, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 25, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 26, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 27, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 28, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 29, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 30, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 31, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 32, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 33, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 34, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 35, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 36, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 37, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 38, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 39, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 40, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 41, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 42, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 43, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 44, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 45, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 45, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 46, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 46, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 47, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 47, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 48, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 48, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 49, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 49, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 50, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 50, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 51, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 51, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 52, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 52, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 53, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 53, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 54, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 54, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 55, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 55, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 56, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 56, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 57, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 57, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 58, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 58, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 59, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 59, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 60, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 60, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 61, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 61, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 62, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 62, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 63, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 64, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 64, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 65, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 66, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 66, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 66.5, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 67, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 67.5, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 67.5, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 68, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 68, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 69, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 69, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 70, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 70, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 71, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 71, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 72, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 72, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 73, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 74, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 75, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 76, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 77, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 77, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 78, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 78, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 79, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 80, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 80, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 81, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 82, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 82, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 83, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 83, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 84, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 84, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 85, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 85, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 86, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 87, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 87, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 88, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 89, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 90, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 91, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 92, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 93, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 94, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 95, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 96, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 97, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 100, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 101, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 102, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 103, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 104, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 105, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 106, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 107, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 108, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 109, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 110, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 111, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 112, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 113, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 114, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 115, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 115, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 116, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 117, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 118, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 119, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 120, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 121, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 122, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 123, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 124, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 125, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 126, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 126, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 127, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 128, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 128.5, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 129, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 129.5, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 130, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 130.5, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 131, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 131.5, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 132, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 133, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 134, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 135, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 136, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 137, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 138, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 139, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 140, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 141, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 142, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 143, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 144, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 145, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 146, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 146, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 147, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 148, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 149, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 150, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 151, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 152, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 152, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 153, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 154, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 155, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 156, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 157, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 158, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 159, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 160, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 160.5, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 161, "_lineIndex": 0, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 161.5, "_lineIndex": 3, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 162, "_lineIndex": 1, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time": 162.5, "_lineIndex": 2, "_lineLayer": 1, "_type": 0, "_cutDirection": 1
# },
# {
#  "_time":